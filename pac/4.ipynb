# %% [markdown]
# <h1> request from public data</h1>

# %%
# !pip install requests
import requests as req
from bs4 import BeautifulSoup as BS
import pandas as pd

# %%
reque = req.get(url="https://www.data.go.kr/data/15076962/openai.do")#, method="get")

soup = BS(reque.text,"html.parser")

policeList = []
# for item in soup.findAll("")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <meta content="width=device-width, initial-scale=1.0, user-scalable=yes" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <title>에러 | 공공데이터포털</title>
# <!-- css -->
# <link href="/css/biz/cmm/tcs/import.css" media="all" rel="stylesheet"/>
# <link href="/css/app.css?t=Wed Oct 04 20:30:07 KST 2023" media="all" rel="stylesheet"/>
# <!-- js -->
# <script src="/js/biz/cmm/tcs/jquery-1.12.4.js"></script>
# <script src="/js/biz/cmm/tcs/jquery-ui.1.12.1.js"></script>
# <script src="/js/biz/cmm/tcs/jquery.easing.1.3.js"></script>
# <script src="/js/biz/cmm/tcs/tooltipster.bundle.js"></script>
# <script src="/js/biz/cmm/tcs/jquery.modal.js"></script>
# <script src="/js/biz/cmm/tcs/dayjs.min.js"></script>
# <script src="/js/biz/cmm/tcs/ui.common.js"></script>
# <script src="/js/biz/cmm/tcs/swiper.min.js"></script>
# <!-- UI/UX팀 작업결과물 -->
# ...

# %%
command + shift + enter

# %% [markdown]
# command + '

# %% [markdown]
# dwdq

# %% [markdown]
# shift + command + '

# %%
option + command + ,

# %%
reque.status_code
# Out:
# 200

# %%
contents = reque.text

# %%
print("하나하나하나하나하나하나하나하나하나하나하나하나하나하나하나하나")
# Out:
# 하나하나하나하나하나하나하나하나하나하나하나하나하나하나하나하나

# %%
# !pip install bs4
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1256 sha256=e48eaa56a955a19a25daf4989a9817388e360272a9143cf6e6ffa21fa9475d62
#   Stored in directory: /Users/jinhojeon/Library/Caches/pip/wheels/d4/c8/5b/b5be9c20e5e4503d04a6eac8a3cd5c2393505c29f02bea0960
# Successfully built bs4
# ...

# %%
contents
# Out:
# b'\n\n\n\n\n\n\n \n\n\n<!doctype html>\n<html lang="ko">\n\t<head>\n\t\t<meta charset="UTF-8">\n\t\t<meta http-equiv="X-UA-Compatible" content="IE=edge" />\n\t\t<meta name="viewport" content="width=device-width, initial-scale=1.0, user-scalable=yes" />\n\t\t<meta name="format-detection" content="telephone=no">\n\n\t\t\n\t\t\n\t\t\t\n\t\t\t\t<meta name="title" property="og:title" content="\xea\xb2\xbd\xec\xb0\xb0\xec\xb2\xad_\xec\xa0\x84\xea\xb5\xad \xec\xb9\x98\xec\x95\x88\xec\x84\xbc\xed\x84\xb0 \xec\xa3\xbc\xec\x86\x8c \xed\x98\x84\xed\x99\xa9_20221231"/>\n\t\t\t\n\t\t\t\n\t\t\n\n\t\t\n\t\t\t\n\t\t\t\t<meta name="description" property="og:description" content="\xea\xb2\xbd\xec\xb0\xb0\xec\xb2\xad \xec\xa0\x84\xea\xb5\xad \xec\xb9\x98\xec\x95\x88\xec\x84\xbc\xed\x84\xb0 \xec\xa3\xbc\xec\x86\x8c\xeb\xa5\xbc \xec\x95\x84\xeb\x9e\x98\xec\x99\x80 \xea\xb0\x99\xec\x9d\xb4 \xed\x98\x84\xed\x96\x89\xed\x99\x94\xed\x95\x98\xec\x98\x80\xec\x8a\xb5\xeb\x8b\x88\xeb\x8b\xa4.&lt;br/&gt;(\xec\x8b
# ...

# %%
# minsu1024@cnu.ac.kr
# 계획서 한장 다음주 월요일까지 
# 현재 팀원들, 추가 멤버 구성, 동아리 이번 학기 운영계획

# %%
dir(reque).index("apparent_encoding")
dir(reque)[37:]
# Out:
# ['apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
reque.status_code
# Out:
# 404

# %%
e
